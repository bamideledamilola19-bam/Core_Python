# %% [markdown]
# # Beginning of python

# %%
print('hello world')
# Out:
# hello world

# %%
print ('hello world')
# Out:
# hello world

# %%
print ('8' + '5')
# Out:
# 85

# %%
empty_list = []
numbers = [1, 2, 3, 4, 5]
fruits = ["apple", "banana", "cherry"]
mixed = [1, "hello", 3.5, True]
nested_list = [1, 2, 3], [4, 5, 6]

print(numbers)
print(fruits[0:2])
# Out:
# [1, 2, 3, 4, 5]
# ['apple', 'banana']

# %%
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(fruits[0])
print(fruits[-1])
# Out:
# apple
# cherry

# %%
names = ['Abiola', 'Benjamin', 'Zainab', 'Esther', 'Caring', 'Salamat']
print(names)
# Out:
# ['Abiola', 'Benjamin', 'Zainab', 'Esther', 'Caring', 'Salamat']

# %%
names[1] = 'Halimah'
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Caring', 'Salamat']

# %%
names = ['Abiola', 'Damilola', 'Zainab', 'Esther', 'Caring', 'Salamat']
print(names)
# Out:
# ['Abiola', 'Damilola', 'Zainab', 'Esther', 'Caring', 'Salamat']

# %%
names[2] = 'Damilola'
print (names)
# Out:
# ['Abiola', 'Damilola', 'Damilola', 'Esther', 'Caring', 'Salamat']

# %%
names = ['Abiola', 'Damilola', 'Zainab', 'Esther', 'Caring', 'Salamat']
print(names)
# Out:
# ['Abiola', 'Damilola', 'Zainab', 'Esther', 'Caring', 'Salamat']

# %%
names.append("lola")   #this is to add (a) new item to the list
print(names)
# Out:
# ['Abiola', 'Damilola', 'Zainab', 'Esther', 'Caring', 'Salamat', 'lola', 'lola']

# %%
fruits = ["apple, orange"]
print(fruits)
# Out:
# ['apple, orange']

# %%
fruits.append("banana")
print(fruits)
# Out:
# ['apple, orange', 'banana']

# %%
fruit = ["apple, banana"]
print(fruits)
# Out:
# ['apple, orange', 'banana']

# %%
more_fruits = ["cherry", "mango"] #this is to add up variables more than 1
fruits.extend(more_fruits)
print(fruits)
# Out:
# ['apple, orange', 'banana', 'cherry', 'mango']

# %%
items = ['Detergent', 'Milk', 'Shoe', 'Fruit']
print(items)
# Out:
# ['Detergent', 'Milk', 'Shoe', 'Fruit']

# %%
items.insert(2, 'Beef')
print(items)
# Out:
# ['Detergent', 'Milk', 'Beef', 'Shoe', 'Fruit']

# %%
fruits = ["apple", 'banana', 'cherry']
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits.remove('apple')  #remove is to remove an item on the list
print(fruits)
# Out:
# ['banana', 'cherry']

# %%
names = ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Funmi', 'Jemilah', 'Lola', 'Hannah']
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Funmi', 'Jemilah', 'Lola', 'Hannah']

# %%
names.pop() #removes the last element and also any number in the pop
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Funmi', 'Jemilah', 'Lola']

# %%
names.pop(5)
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Funmi', 'Jemilah', 'Lola']

# %%
poped_name = names.pop(5)
print(poped_name)
print(names)
# Out:
# Jemilah
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Lola']

# %%
poped_name = names.pop(3)   #it counts from 0, hence it removes esther
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Carina', 'Lola']

# %%
names = ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina',]
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina']

# %%
names.reverse() #this reverses the list directly #assignment find out the other way wecan reverse a python
print(names)
# Out:
# ['Carina', 'Esther', 'Zainab', 'Halimah', 'Abiola']

# %%
numbers = [1, 2, 3, 4, 3, 3, 3] #this is used to count the number of times the number asked appears
print(numbers.count(3))
# Out:
# 4

# %%
cars = ['Tesla', 'Honda', 'Benz', 'Ford', 'Cheving', 'Audi', 'Toyota']
print(cars)
# Out:
# ['Tesla', 'Honda', 'Benz', 'Ford', 'Cheving', 'Audi', 'Toyota']

# %%
cars.sort() #this is ascending by alphabetical order
print(cars)
# Out:
# ['Audi', 'Benz', 'Cheving', 'Ford', 'Honda', 'Tesla', 'Toyota']

# %%
cars.sort(reverse=True) #this is to arrange from behind, opp of alphabetical
print(cars)
# Out:
# ['Toyota', 'Tesla', 'Honda', 'Ford', 'Cheving', 'Benz', 'Audi']

# %%
numbers = [3, 2, 1] #this is a reverse mthd
numbers.reverse()
print(numbers)
# Out:
# [1, 2, 3]

# %%
numbers = [1, 2, 3] #this is a slicing method
reversed_numbers = numbers[::-1]
print(reversed_numbers)
# Out:
# [3, 2, 1]

# %%
names = ['Abiola', 'Lola', 'Lola', 'Lola']   
names_copy = names.copy()

# %%
names_copy.append('Ramat')
print(names_copy)
# Out:
# ['Abiola', 'Lola', 'Lola', 'Lola', 'Ramat']

# %%
print(names)
# Out:
# ['Abiola', 'Lola', 'Lola', 'Lola']

# %%
names_copy = names.copy()
print(names_copy)
# Out:
# ['Abiola', 'Lola', 'Lola', 'Lola']

# %%
names_copy.clear()
print(names_copy)
# Out:
# []

# %%
names = ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Funmi', 'Jemilah', 'Lola', 'Hannah']
print(names)

names.reverse()
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'Funmi', 'Jemilah', 'Lola', 'Hannah']
# ['Hannah', 'Lola', 'Jemilah', 'Funmi', 'Salamat', 'Carina', 'Esther', 'Zainab', 'Halimah', 'Abiola']

# %%
empty_set = set()
fruits = {"apple", "banana", "cherry"}
numbers = {7, 3, 9, 1, 2, 3, 4, 5,}
mixed = {1, "hello", 3, 5, True}

xyz = {5, 8, 4}
print(numbers)
print(xyz)
# Out:
# {1, 2, 3, 4, 5, 7, 9}
# {8, 4, 5}

# %%
print(1==True)
print(0==False)
# Out:
# True
# True

# %%
# 0== False
# 1==True
x = {1, 2, 3, True} #with true and 1 it will only pick
print(x)
# print(''==True)
# Out:
# {1, 2, 3}

# %%
# 0== False
# 1==True
x = {2, 3, True} #without the 1 it printed true 
print(x)
# print(''==True)
# Out:
# {True, 2, 3}

# %%
fruits = {"apple", "banana"}
fruits.add("cherry") a
print(fruits)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
fruits = {"apple", "banana"}
fruits.update(("cherry", "orange")) # update is for joining more than 1 set
print(fruits)
# Out:
# {'cherry', 'orange', 'banana', 'apple'}

# %%
fruits = {"apple", "banana", "mango", "pineapple"}
fruits.add("cherry")
print(fruits)
# Out:
# {'cherry', 'mango', 'apple', 'pineapple', 'banana'}

# %%
fruits = {"apple", "banana", "cherry"}
fruits.remove("banana")
print(fruits)
# Out:
# {'cherry', 'apple'}

# %%
fruits = {"apple", "banana", "guava", "cherry"}
fruits.remove("guava") # only use remove when the item is in the set. 
print(fruits)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
fruits = {"apple", "banana", "cherry"}
print(fruits)
fruits.discard("banana") # discard is better if you're not sure of the item
print(fruits)
# Out:
# {'cherry', 'banana', 'apple'}
# {'cherry', 'apple'}

# %%
fruits.discard("grape") # No error, even though 'grape' is not in the set
print(fruits)
# Out:
# {'cherry', 'apple'}

# %%
fruits = {"apple", "banana", "cherry"}
fruits.pop() # pop removes one of the fruits in the set
print(fruits)
# Out:
# {'banana', 'apple'}

# %%
fruits = {"apple", "banana", "cherry"}
fruits.clear() # this removes all the items
print(fruits)
# Out:
# set()

# %%
set1 = {1, 2, 3}
set2 = {3, 4, 5}
result = set1.union(set2) # used for joining sets
print(result)
# Out:
# {1, 2, 3, 4, 5}

# %%
result = set1 | set2
print(result) #the pipe symbol is another way of union
# Out:
# {1, 2, 3, 4, 5}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
result = set1.intersection(set2)
print(result)
# Out:
# {3, 4}

# %%
result = set1 & set2
print(result) #the hamper symbol is the shorter way to solve it
# Out:
# {3, 4}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
result = set1.difference(set2)
print(result)
# Out:
# {1, 2}

# %%
result = set1 - set2
print(result) #the minus symbol is the short way
# Out:
# {1, 2}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
result = set2.difference(set1)
print(result)
# Out:
# {5, 6}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
result = set1.symmetric_difference(set2)
print(result)
# Out:
# {1, 2, 5, 6}

# %%
result = set1 ^ set2
print(result) #the caret^ symbol is for differerence)opp of intersection
# Out:
# {1, 2, 5, 6}

# %%
set1 = {1, 2}
set2 = {1, 2, 3, 4} #checking for comparison double eqaulTo(==)
print(set1.issubset(set2))
# Out:
# True

# %%
print(set1 <= set2) #shorter way of comparing(lessthanequal)
# Out:
# True

# %%
set1 = {1, 2, 3, 4}
set2 = {1, 2}
print(set1.issuperset(set2)) #supersetIStheOppositeOfsubset
# Out:
# True

# %%
print(set1 >= set2) #this is using the greaterThan/equaltoShort form
# Out:
# True

# %%
set1 = {1, 2, 3, 4, 5, 6, 7, 9}
set2 = {7, 9, 3}
print(set1 >= set2)
# Out:
# True

# %%
us = {1, 2, 3, 4, 5, 6, 7, 8}
set1 = {1, 2, 3}
set2 = {4, 5, 6}
print(set1.isdisjoint(set2))
# Out:
# True

# %%
us = {1, 2, 3, 4, 5, 6, 7, 8}
set1 = {1, 2, 3}
set2 = {9}
print(set1.isdisjoint(set2))
# Out:
# True

# %%
us = {1, 2, 3, 4, 5, 6, 7, 8}
set1 = {1, 2, 3}
set2 = {6, 7, 4}
print(set1.isdisjoint(set2))
# Out:
# True

# %%
numbers = {1, 2, 3, 4, 5}
print(len(numbers))
# Out:
# 5

# %%
fruits = {"apple", "banana", "cherry"}
print("banana" in fruits)
# Out:
# True

# %% [markdown]
# # dictionary

# %%
person = {
"name": "Tomi",
"age": 20,
"city": "Ilorin"
}
numbers = {1: "One", 2: "Two", 3: "Three"} # Keys can be integers
mixed_keys = {"name": "Zainab", 42: "Answer", (1, 2): "Tuple as key"}
print(person['name'])
# Out:
# Tomi

# %%
person = {
"name": 'Lola',
"age": 27,
"city": "Ilorin",
'name': 'Funmi',
}
print(person["name"])
print(person["age"])
# Out:
# Funmi
# 27

# %%
person = {
"name": 'Rukky',
"age": 25,
"city": "Ilorin",
'name': 'Tope',
}
print(person["name"])
print(person["age"])
# Out:
# Tope
# 25

# %%
person = {
"name": 'Tomi',
"age": 15,
"city": "Ilorin",
'name': 'Salamat',
}
print(person["salary"]) #this is how an error runned code looked
print(person["salary"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 7
#       1 person = {
#       2 "name": 'Tomi',
#       3 "age": 15,
#       4 "city": "Ilorin",
#       5 'name': 'Salamat',
#       6 }
# ----> 7 print(person["salary"])
#       8 print(person["salary"])
#
# KeyError: 'salary'

# %%
print(person.get("name"))
print(person.get("salary"))
print(person.get("salary", "Not Available"))
# Out:
# Salamat
# None
# Not Available

# %%
print(person.get("name"))
print(person.get("salary"))
print(person.get("salary", "invalid"))
# Out:
# Salamat
# None
# invalid

# %%
student = {
"name": "Abiola",
"age": 15
}
print(student)
student["city"] = "Ilorin"
print(student)
# Out:
# {'name': 'Abiola', 'age': 15}
# {'name': 'Abiola', 'age': 15, 'city': 'Ilorin'}

# %%
student = {
"name": "Lola",
"age": 30
}    
print(student)
student["city"] = "ilorin"
print(student)
# Out:
# {'name': 'Lola', 'age': 30}
# {'name': 'Lola', 'age': 30, 'city': 'ilorin'}

# %%
student["age"] = 30 #the short input form
print(student)
# Out:
# {'name': 'Lola', 'age': 30, 'city': 'ilorin'}

# %%
person = {"name": 'Lola', "age": 15, "city": "Lagos"}
print(person)
person.pop("age")
print(person)
# Out:
# {'name': 'Lola', 'age': 15, 'city': 'Lagos'}
# {'name': 'Lola', 'city': 'Lagos'}

# %%
person = {"name": "Esther", "age": 15, "city": "Ilorin"}
print(person)
person.popitem()
print(person)
# Out:
# {'name': 'Esther', 'age': 15, 'city': 'Ilorin'}
# {'name': 'Esther', 'age': 15}

# %%
person = {"name": "Funmi", "age": 15, "city": "Basin"}
print(person)
person.popitem()
print(person)
# Out:
# {'name': 'Funmi', 'age': 15, 'city': 'Basin'}
# {'name': 'Funmi', 'age': 15}

# %%
person = {"name": "Rachealr", "age": 15, "city": "Osin"}
print(person)
person.popitem() #deletes the last item
print(person)
# Out:
# {'name': 'Rachealr', 'age': 15, 'city': 'Osin'}
# {'name': 'Rachealr', 'age': 15}

# %%
person = {"name": "Nofisat", "age": 22, "city": "Lagos"}
print(person)
del person["city"] #delete works like popitem
print(person)
# Out:
# {'name': 'Nofisat', 'age': 22, 'city': 'Lagos'}
# {'name': 'Nofisat', 'age': 22}

# %%
person = {"name": "Adeola", "age": 15, "city": "Ilorin"}
print(person)
person.clear()
print(person)
# Out:
# {'name': 'Adeola', 'age': 15, 'city': 'Ilorin'}
# {}

# %%
person = {"name": "Titi", "age": 15, "city": "Ilorin"}
print(person)
person.clear()
print(person)
# Out:
# {'name': 'Titi', 'age': 15, 'city': 'Ilorin'}
# {}

# %% [markdown]
# # Dictionary Methods

# %%
person = {"name": "Ramat", "age": 15, "city": "Ilorin"}
print(person)
print(person.keys()) #this is how to returns keys
# Out:
# {'name': 'Ramat', 'age': 15, 'city': 'Ilorin'}
# dict_keys(['name', 'age', 'city'])

# %%
print(person.values())
# Out:
# dict_values(['Ramat', 15, 'Ilorin'])

# %%
person = {"name": "Jemilah", "age": 15}
print(person)
new_data = {"city": "Ilorin", "age": 25}
person.update(new_data)
print(person)
# Out:
# {'name': 'Jemilah', 'age': 15}
# {'name': 'Jemilah', 'age': 25, 'city': 'Ilorin'}

# %%
person = {"name": "Lola", "age": 20}
print(person)
new_data = {"city": "Ilorin", "age": 20, "salary": 50}
person.update(new_data) 
print(person)
# Out:
# {'name': 'Lola', 'age': 20}
# {'name': 'Lola', 'age': 20, 'city': 'Ilorin', 'salary': 50}

# %%
person = {"name": "Jane", "age": 20}
print(person)
print("name" in person)
print("salary" in person)
# Out:
# {'name': 'Jane', 'age': 20}
# True
# False

# %%
person = {"name": "Jane", "age": 20}
print(person)
print("name" in person)
print("age" in person)
# Out:
# {'name': 'Jane', 'age': 20}
# True
# True

# %%
person = {"name": "LolaFunmi", "age": 40, "city": "Ilorin"}
print(person)
copy_dict = person.copy()
print(copy_dict)
# Out:
# {'name': 'LolaFunmi', 'age': 40, 'city': 'Ilorin'}
# {'name': 'LolaFunmi', 'age': 40, 'city': 'Ilorin'}

# %%
print(len(person))
# Out:
# 3

# %%
student = {
"name": "Rukayat",
"grades": {"math": 90, "science": 85}
}
print(student["grades"]["math"])
# Out:
# 90

# %%
student = {
"name": "Lola",
"grades": {"eng": 80, "science": 100, "bio": 100}
}
print(student["grades"]["bio"])
# Out:
# 100

# %%
student = {
"name": "Lola",
"info": { "hobbies": ['reading', 'sleeping', 'cooking']}
}
print(student["info"]["hobbies"][1])
# Out:
# sleeping

# %%
student = {
"name": "Lola",
"info": { "hobbies": ['reading', 'sleeping', 'dancing', 'driving', 'cooking']}
}
print(student["info"]["hobbies"][3])
# Out:
# drivingcooking

# %%
student = {
"name": "Lola",
"info": { "hobbies": ['reading', 'sleeping', 'dancing', 'driving', 'cooking']}
}
print(student["info"]["hobbies"][-2])
# Out:
# driving

# %%
student = {
"name": "Lola",
"info": { "hobbies": ['reading', 'sleeping', 'dancing', 'driving', 'cooking']}
}
print(student["info"]["hobbies"][3:])
# Out:
# ['driving', 'cooking']

# %%
student = {
"name": "Lola",
"info": { "hobbies": ['reading', 'sleeping', 'dancing', 'driving', 'cooking']}
}
print(student["info"]["hobbies"][3:])
# Out:
# ['driving', 'cooking']

# %%
import math

print(math.pi)
print(math.e) 
print(math.inf) 
print(-math.inf)
# Out:
# 3.141592653589793
# 2.718281828459045
# inf
# -inf

# %%
reservation_a = ((1, 1), (1, 2), (2, 1), (2, 3))
reservation_b = ((2, 1),(2, 2), (1, 1),(3, 3))

print(set(reservation_a) & set(reservation_b))
# Out:
# {(1, 1), (2, 1)}

# %%
num_int = 5
num_float = num_int + 2.5 

print(num_float)
print(type(num_float))
# Out:
# 7.5
# <class 'float'>

# %%
num_complex = num_int + 3j 

print(num_complex)
print(type(num_complex))
# Out:
# (5+3j)
# <class 'complex'>

# %%
8/2
# Out:
# 4.0

# %%
num_float = 7.0
num_int = int(num_float)

print(num_int) 
print(type(num_int))
# Out:
# 7
# <class 'int'>

# %%
num_str = "123"
num_int = int(num_str) 

print(num_int) 
print(type(num_int))
# Out:
# 123
# <class 'int'>

# %%
age = 25
age_str = str(age) # Converts integer to string

print(age_str) # Output: "25"
print(type(age_str)) # Output: <class 'str'>
# Out:
# 25
# <class 'str'>

# %%
my_list = [1, 2, 3, 4]
my_tuple = tuple(my_list)

print(my_tuple) # Output: (1, 2, 3, 4)
print(type(my_tuple)) # Output: <class 'tuple'>
# Out:
# (1, 2, 3, 4)
# <class 'tuple'>

# %%
age = input("Enter your age: ")

print(type(age))
print(f"You are {age} years old.")
# Out:
# Enter your age:  yyyt
# <class 'str'>
# You are yyyt years old.

# %%
name = input ("Enter your name: ")
print (f"Hello, {name.upper()}!")
# Out:
# Enter your name:  BAMIDELE DAMILOLA RACHEAL
# Hello, BAMIDELE DAMILOLA RACHEAL!

# %%
age = int(input("Enter your age: "))
print(type(age))
print(f"You are {age} years old.")
# Out:
# Enter your age:  20
# <class 'int'>
# You are 20 years old.

# %%
age = int(input("enter your age: "))
print(type(age))
print(f"You are {age} years old.")
# Out:
# enter your age:  44
# <class 'int'>
# You are 44 years old.

# %%
is_student = bool(int(input("Are you a student? Enter 1 for Yes, 0 for No: ")))
print(f"Student status: {is_student}")
# Out:
# Are you a student? Enter 1 for Yes, 0 for No:  0
# Student status: False

# %%
xyz = input('enter full name: ')
input(xyz.split())
# Out:
# enter full name:  Bamidele Damilola
# ['Bamidele', 'Damilola'] Lola
# 'Lola'

# %%
xyz = input('enter full name: ')
print(xyz.split())
# Out:
# enter full name:  bamidele damilola
# ['bamidele', 'damilola']

# %% [markdown]
# # Mathematical Modules

# %%
import math

# %%
print(math.pi)
print(math.e) # e here is Euler"s constant
print(math.inf) 
print(-math.inf)
# Out:
# 3.141592653589793
# 2.718281828459045
# inf
# -inf

# %%
math.sqrt(16) # always add value to the box, the answers will be in float as in decimal
# Out:
# 4.0

# %%
print(math.pow(2, 3))  
print(2**3.0) #the double asterick is for power
print(2*3) #the single is for multiplication
# Out:
# 8.0
# 8.0
# 6

# %% [markdown]
# # Rounding and Truncation

# %%
print(math.floor(4.7))
print(math.ceil(4.1))
# Out:
# 4
# 5

# %%
print(math.log(10))
print(math.log(10, 2))
# Out:
# 2.302585092994046
# 3.3219280948873626

# %%
print(math.log10(100))
# Out:
# 2.0

# %%
print(math.sin(10))
print(math.cos(90)) #trigonometric functions
print(math.tan(math.pi/4))
# Out:
# -0.5440211108893698
# -0.4480736161291701
# 0.9999999999999999

# %%
print(math.asin(1)) #the inverse of trigonometric functions
print(math.acos(0))
print(math.atan(1))
# Out:
# 1.5707963267948966
# 1.5707963267948966
# 0.7853981633974483

# %% [markdown]
# # using alias in python

# %%
import math as m #using m in place of writing full math

# %%
m.pi
# Out:
# 3.141592653589793

# %%
import random

# %%
# generating random numbers

random_num = random.random()
print(random_num)
# Out:
# 0.14456678502753662

# %%
random_num = random.random()
print(random_num)
# Out:
# 0.5807427551670754

# %%
random_num = random.randint(1, 10)
print(random_num)
# Out:
# 6

# %%
random_num = random.randint(1, 10)
random_num #the randint is to get the interger in a range given
# Out:
# 8

# %%
random_num = random.randint(1, 5)
print(random_num)
# Out:
# 3

# %%
# random_num random.Uniform

# %%
random_num = random.uniform(1, 5)
print(random_num)
# Out:
# 3.283980096529596

# %%
names = ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Lola', 'Carina', 'Salamat', 'Funmi', 'Zainab', 'Jamilah', 'Lola', 'Hannah']
x = [1, 23, 4, 5, 7]
random_name = random.choice(x) #to be used only for a collection
print(random_name) #picking a random choice of name in the list
# Out:
# 23

# %%
names = ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Lola', 'Carina', 'Salamat', 'Funmi', 'Zainab', 'Jamilah', 'Lola', 'Hannah']
x = [1, 23, 4, 5, 7]
random_name = random.choice(names) #to be used only for a collection
print(random_name) #picking a random choice of name in the list
# Out:
# Lola

# %%
two_random_names = random.sample(names, 2)
print(two_random_names)
# Out:
# ['Jamilah', 'Lola']

# %%
two_random_names = random.sample(names, 3)
print(two_random_names)
# Out:
# ['Lola', 'Halimah', 'Zainab']

# %% [markdown]
# # Randomly shuffle a list

# %%
names = ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Lola', 'Carina', 'Salamat', 'Funmi', 'Zainab', 'Jamilah', 'Lola', 'Hannah']

random.shuffle(names)
print(names)
# Out:
# ['Salamat', 'Zainab', 'Jamilah', 'Esther', 'Carina', 'Funmi', 'Zainab', 'Lola', 'Abiola', 'Hannah', 'Lola', 'Halimah']

# %%
random_num = random.randint(1, 20)
print(random_num)
print(random_num**2)
# Out:
# 9
# 81

# %%
print(random_num)
# Out:
# 9

# %% [markdown]
# # Python operators

# %%
a = 10
b = 3
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a ** b)
print(f'10 divide 3 is {a // b}, and the remainder is {(a % b)} ')
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000
# 10 divide 3 is 3, and the remainder is 1

# %%
a = 20
b = 5
print(a % b)
print(a ** b)
# Out:
# 0
# 3200000

# %%
x = 10
y = 5
print(x == y) #IS equal to
print(x != y) #IS Not equal to
print(x > y) #IS greater than
print(x < y) #IS less than
print(x >= y) #IS greater than or equal to
print(x <= y) #IS less than or equal to
# Out:
# False
# True
# True
# False
# True
# False

# %%
#BINARY EXPRERSSION 

a = 5 # Binary: 101
b = 3 # Binary: 011
print(a & b) # 1 (Binary: 001)
print(a | b) # 7 (Binary: 111)
print(a ^ b) # 6 (Binary: 110)
print(~a) # -6 (Binary: -(101+1))
print(a << 1) # 10 (Binary: 1010)
print(a >> 1) # 2 (Binary: 10)
# Out:
# 1
# 7
# 6
# -6
# 10
# 2

# %%
x = 10
x += 5 # could also be said to be x + 5

print(x)
x *= 2
print(x)
x -= 4
print(x)
# Out:
# 15
# 30
# 26

# %%
x = 20
x += 10 # could also be said to be x + 5

print(x)
x *= 2
print(x)
x -= 4
print(x)
# Out:
# 30
# 60
# 56

# %%
balance = 100000
credit = 200000
balance += credit
balance
# Out:
# 300000

# %%
balance = 3100000
credit = 200000
balance -= credit
balance
# Out:
# 2900000

# %%
balance = 3100000
credit = 200000

balance // credit #balance = balance  debit
balance
# Out:
# 3100000

# %%
balance = 20
debit = 3 
# balance = balance % debit
balance %= debit
balance
# Out:
# 2
